# %%
import pandas as pd

# 1. Carga del pergamino secreto
df = pd.read_csv('registros_misiones.csv')
df
# Out:
#          id_reg                   ts     nin_id      aldea   chakra rango  \
# 0     ANBU-1000  2025-02-02 11:11:00      Gaara       suna   998.21     S
# 1     ANBU-1001  2025-02-04 10:31:00     Temari     Konoha  6441.64     A
# 2     ANBU-1002  2025-02-02 23:07:00  Shikamaru      Suna       NaN     D
# 3     ANBU-1003  2025-02-04 05:00:00      Choji  Amegakure  1966.92     B
# 4     ANBU-1004  2025-02-05 14:13:00     Temari       Kiri  1205.96     S
# ...         ...                  ...        ...        ...      ...   ...
# 1545  ANBU-1957  2025-02-04 04:32:00     Temari       Kumo  7202.06     C
# 1546  ANBU-1138  2025-02-03 08:46:00    Kankuro       Kiri  2591.10     A
# 1547  ANBU-1061  2025-02-02 07:38:00     Temari       Suna      NaN     C
# 1548  ANBU-2226  2025-02-04 01:03:00     Sasuke     Konoha  6520.41     C
# 1549  ANBU-2498  2025-02-05 00:10:00     Naruto       Kumo  2791.26     C
#
#           status                                   desc
# 0          Éxito          Vigilancia de puesto avanzado
# 1          Éxito  Misión de reconocimiento en fronteras
# 2          Fallo        Movimiento sospechoso detectado
# 3     Sospechoso                Posible espía detectado
# 4          Éxito                 Escolta de persona VIP
# ...          ...                                    ...
# 1545       Fallo                 Escolta de persona VIP
# 1546       Éxito                Posible espía detectado
# 1547       Fallo                Posible espía detectado
# 1548    En curso                     Patrulla rutinaria
# 1549  Sospechoso                 Escolta de persona VIP
#
# [1550 rows x 8 columns]

# %%
# --- SECCIÓN 1: LIMPIEZA DE DATOS ---

def limpiar_registro(df):
    # Reto 1: Elimina filas duplicadas.
    df = df.drop_duplicates()

    # Reto 2: Estandariza la columna 'aldea' (quitar espacios, solventar mayúsculas/minúsculas).
    df["aldea"] = df["aldea"].str.lower().str.strip()

    # Reto 3: Si 'nin_id' es nulo y la 'aldea' es 'Kiri', rellena con 'Ninja de la Niebla Anonimo'.
    df.loc[df['nin_id'].isna() & (df['aldea'] == 'Kiri'), 'nin_id'] = 'Ninja de la Niebla Anonimo'

    # Reto 4: Convierte 'ts' a datetime.
    df['ts'] = pd.to_datetime(df['ts'], errors='coerce')

    # Reto 5: Filtra o corrige niveles de chakra imposibles (<= 0 o > 100.000).
    df = df[(df['chakra'] > 0) & (df['chakra'] <= 100000)]

    # Reto 6: Renombra las columnas:
    df = df.rename(columns={
        'id_reg': 'ID',
        'ts': 'Fecha',
        'nin_id': 'Ninja',
        'status': 'Estado',
        'desc': 'Descripcion'
    })
    # Tu código aquí
    return df

# %%
# --- SECCIÓN 2: BÚSQUEDA Y CONSULTAS ---

def realizar_consultas(df):

    # Reto 7: Busca descripciones con las palabras 'espía', 'sospechoso' o 'enemigo'.
    resultado1 = df[df['Descripcion'].str.contains('espía', case=False, na=False)]

    resultado2 = df[df['Descripcion'].str.contains('sospechoso', case=False, na=False)]

    resultado3 = df[df['Descripcion'].str.contains('enemigo', case=False, na=False)]
    print("\n--- Reto 7 ---")
    print(resultado1,resultado2,resultado3)

    # Reto 8: Filtra ninjas de la 'Aldea de la Lluvia' (Amegakure) con chakra > 5000 y rango != 'D'.
    reto8 = df[
        (df['aldea'] == 'Amegakure') &
        (df['chakra'] > 5000) &
        (df['rango'] != 'D')
    ]
    print("\n--- Reto 8 ---")
    print(reto8)
    # Reto 9: Encuentra los accesos ocurridos de madrugada (entre las 23:00 y las 05:00).
    horas = df['Fecha'].dt.hour
    reto9 = df[(horas >= 23) | (horas <= 5)]
    print("\n--- Reto 9 ---")
    print(reto9)
    # Reto 10: Obtén el Top 5 ninjas con más chakra de cada aldea.
    reto10 = (
        df.sort_values('chakra', ascending=False)
        .groupby('aldea')
        .head(5)
        .sort_values('aldea')
    )
    print("\n--- Reto 10 ---")
    print(reto10)
    # Reto 11: Lista misiones de ninjas que NO pertenecen a la alianza (Konoha, Suna, Kumo).
    # Reto 12: Cuenta cuántas misiones de estado 'Fallo' hay por cada aldea.

    # Tu código aquí
    pass

# --- EJECUCIÓN DEL PROTOCOLO ANBU ---
print("Iniciando Rastreo de Chakra de Rodrigo Bueno...")
df_limpio = limpiar_registro(df)
realizar_consultas(df_limpio)
df_limpio.to_csv('misiones_limpias_Rodrigo Bueno.csv', index=False)
# Out:
# Iniciando Rastreo de Chakra de Rodrigo Bueno...
#
# --- Reto 7 ---
#              ID               Fecha      Ninja      aldea   chakra rango  \
# 3     ANBU-1003 2025-02-04 05:00:00      Choji  amegakure  1966.92     B
# 9     ANBU-1009 2025-02-03 16:05:00  Shikamaru        iwa  7423.79     C
# 11    ANBU-1011 2025-02-03 16:36:00    Kakashi       suna  4993.73     D
# 17    ANBU-1017 2025-02-01 06:06:00    Kankuro        iwa  3955.04     B
# 40    ANBU-1040 2025-02-05 15:19:00    Kankuro       kumo  7009.62     S
# ...         ...                 ...        ...        ...      ...   ...
# 1463  ANBU-2463 2025-02-06 15:52:00     Temari       kiri  6936.35     A
# 1472  ANBU-2472 2025-02-06 21:51:00    Kakashi        iwa  3137.50     S
# 1482  ANBU-2482 2025-02-05 07:58:00        Ino     konoha  1688.05     D
# 1487  ANBU-2487 2025-02-04 18:11:00     Sakura        iwa  2597.15     C
# 1492  ANBU-2492 2025-02-05 16:09:00      Gaara       suna  5496.61     C
#
#           Estado              Descripcion
# 3     Sospechoso  Posible espía detectado
# 9          Fallo  Posible espía detectado
# 11         Fallo  Posible espía detectado
# 17         Éxito  Posible espía detectado
# 40         Éxito  Posible espía detectado
# ...          ...                      ...
# 1463  Sospechoso  Posible espía detectado
# 1472    En curso  Posible espía detectado
# 1482    En curso  Posible espía detectado
# 1487       Éxito  Posible espía detectado
# 1492  Sospechoso  Posible espía detectado
#
# [176 rows x 8 columns]              ID               Fecha    Ninja      aldea   chakra rango  \
# 5     ANBU-1005 2025-02-01 16:21:00  Kakashi       suna  5955.33     S
# 64    ANBU-1064 2025-02-01 02:14:00   Sakura     konoha  7795.43     B
# 66    ANBU-1066 2025-02-03 02:05:00      Ino        iwa  2230.37     D
# 67    ANBU-1067 2025-02-01 23:02:00  Kakashi        iwa  4899.79     S
# 74    ANBU-1074 2025-02-06 02:16:00    Gaara  amegakure  2512.29     B
# ...         ...                 ...      ...        ...      ...   ...
# 1474  ANBU-2474 2025-02-01 07:18:00   Sakura       kumo  1934.96     A
# 1476  ANBU-2476 2025-02-02 02:51:00   Naruto        iwa  1359.35     S
# 1484  ANBU-2484 2025-02-02 06:32:00    Gaara       kumo  7508.28     A
# 1496  ANBU-2496 2025-02-01 05:01:00   Sakura       kumo  3261.14     D
# 1523  ANBU-1257 2025-02-01 14:41:00    Gaara     konoha  3094.07     B
#
#           Estado                      Descripcion
# 5       En curso  Movimiento sospechoso detectado
# 64      En curso  Movimiento sospechoso detectado
# 66         Fallo  Movimiento sospechoso detectado
# 67         Fallo  Movimiento sospechoso detectado
# 74         Éxito  Movimiento sospechoso detectado
# ...          ...                              ...
# 1474    En curso  Movimiento sospechoso detectado
# 1476  Sospechoso  Movimiento sospechoso detectado
# 1484    En curso  Movimiento sospechoso detectado
# 1496    En curso  Movimiento sospechoso detectado
# 1523  Sospechoso  Movimiento sospechoso detectado
#
# [169 rows x 8 columns]              ID               Fecha      Ninja      aldea   chakra rango  \
# 8     ANBU-1008 2025-02-01 12:31:00      Gaara       kumo  1053.53     C
# 15    ANBU-1015 2025-02-05 03:58:00      Gaara  amegakure  3647.12     S
# 28    ANBU-1028 2025-02-06 21:28:00    Kankuro     konoha  4725.75     A
# 38    ANBU-1038 2025-02-06 04:21:00    Kakashi       kumo   943.11     B
# 43    ANBU-1043 2025-02-02 16:15:00        NaN       kiri  4302.23     A
# ...         ...                 ...        ...        ...      ...   ...
# 1440  ANBU-2440 2025-02-01 05:23:00     Temari  amegakure  1131.86     A
# 1443  ANBU-2443 2025-02-04 08:23:00     Naruto       suna  2344.07     C
# 1456  ANBU-2456 2025-02-04 04:36:00  Shikamaru       kiri   599.54     S
# 1475  ANBU-2475 2025-02-01 12:52:00        Ino        iwa   615.54     B
# 1495  ANBU-2495 2025-02-06 08:44:00        Ino       suna  4846.80     D
#
#           Estado         Descripcion
# 8       En curso  Enemigo a la vista
# 15         Éxito  Enemigo a la vista
# 28      En curso  Enemigo a la vista
# 38      En curso  Enemigo a la vista
# 43      En curso  Enemigo a la vista
# ...          ...                 ...
# 1440    En curso  Enemigo a la vista
# 1443       Éxito  Enemigo a la vista
# 1456  Sospechoso  Enemigo a la vista
# 1475       Fallo  Enemigo a la vista
# 1495  Sospechoso  Enemigo a la vista
#
# [158 rows x 8 columns]
#
# --- Reto 8 ---
# Empty DataFrame
# Columns: [ID, Fecha, Ninja, aldea, chakra, rango, Estado, Descripcion]
# Index: []
#
# --- Reto 9 ---
#              ID               Fecha      Ninja      aldea   chakra rango  \
# 3     ANBU-1003 2025-02-04 05:00:00      Choji  amegakure  1966.92     B
# 10    ANBU-1010 2025-02-04 01:47:00     Temari       suna  5538.98     B
# 14    ANBU-1014 2025-02-04 04:27:00     Sasuke       kiri  4950.96     S
# 15    ANBU-1015 2025-02-05 03:58:00      Gaara  amegakure  3647.12     S
# 19    ANBU-1019 2025-02-03 03:54:00     Sakura     konoha   562.25     D
# ...         ...                 ...        ...        ...      ...   ...
# 1480  ANBU-2480 2025-02-03 00:58:00     Sakura       kumo  6751.01     S
# 1494  ANBU-2494 2025-02-02 01:54:00  Shikamaru     konoha  4911.78     B
# 1496  ANBU-2496 2025-02-01 05:01:00     Sakura       kumo  3261.14     D
# 1497  ANBU-2497 2025-02-06 03:34:00    Kakashi       kumo  5836.87     S
# 1498  ANBU-2498 2025-02-05 00:10:00     Naruto       kumo  2791.26     C
#
#           Estado                      Descripcion
# 3     Sospechoso          Posible espía detectado
# 10         Éxito          Sustitución de guardias
# 14    Sospechoso           Escolta de persona VIP
# 15         Éxito               Enemigo a la vista
# 19      En curso               Patrulla rutinaria
# ...          ...                              ...
# 1480       Fallo               Patrulla rutinaria
# 1494    En curso           Escolta de persona VIP
# 1496    En curso  Movimiento sospechoso detectado
# 1497    En curso           Escolta de persona VIP
# 1498  Sospechoso           Escolta de persona VIP
#
# [432 rows x 8 columns]
#
# --- Reto 10 ---
#              ID               Fecha      Ninja      aldea   chakra rango  \
# 1221  ANBU-2221 2025-02-05 23:32:00    Kakashi  amegakure  7983.00     S
# 742   ANBU-1742 2025-02-01 07:55:00  Shikamaru  amegakure  7854.29     B
# 512   ANBU-1512 2025-02-03 21:07:00     Temari  amegakure  7858.00     S
# 1232  ANBU-2232 2025-02-05 06:03:00     Naruto  amegakure  7899.15     A
# 1263  ANBU-2263 2025-02-02 20:57:00     Temari  amegakure  7928.67     C
# 530   ANBU-1530 2025-02-04 13:45:00     Temari        iwa  7762.98     A
# 738   ANBU-1738 2025-02-05 02:57:00  Shikamaru        iwa  7773.71     S
# 777   ANBU-1777 2025-02-05 16:23:00    Kankuro        iwa  7780.78     A
# 1104  ANBU-2104 2025-02-06 00:52:00  Shikamaru        iwa  7801.30     S
# 1100  ANBU-2100 2025-02-06 03:45:00    Kakashi        iwa  7938.99     S
# 1292  ANBU-2292 2025-02-06 23:42:00     Sasuke       kiri  7847.02     A
# 216   ANBU-1216 2025-02-01 10:49:00    Kankuro       kiri  7855.79     D
# 637   ANBU-1637 2025-02-02 23:06:00        NaN       kiri  7905.62     B
# 150   ANBU-1150 2025-02-01 08:08:00        NaN       kiri  7858.65     C
# 987   ANBU-1987 2025-02-01 12:31:00     Temari       kiri  7940.84     D
# 1002  ANBU-2002 2025-02-01 17:33:00      Choji     konoha  7950.38     A
# 340   ANBU-1340 2025-02-06 05:27:00     Naruto     konoha  7968.97     A
# 1416  ANBU-2416 2025-02-02 06:46:00      Choji     konoha  7950.41     A
# 467   ANBU-1467 2025-02-04 22:55:00        Ino     konoha  7951.51     D
# 277   ANBU-1277 2025-02-06 19:58:00     Sasuke     konoha  7938.08     C
# 1060  ANBU-2060 2025-02-04 07:40:00     Naruto    konoha_  6135.50     B
# 172   ANBU-1172 2025-02-03 04:10:00     Temari    konoha_  6167.94     B
# 899   ANBU-1899 2025-02-02 10:57:00  Shikamaru    konoha_  7614.45     A
# 1048  ANBU-2048 2025-02-02 04:52:00        Ino    konoha_  3549.28     D
# 885   ANBU-1885 2025-02-01 12:32:00        Ino    konoha_  5138.54     D
# 286   ANBU-1286 2025-02-06 00:05:00     Temari       kumo  7956.86     B
# 634   ANBU-1634 2025-02-02 05:14:00    Kankuro       kumo  7837.67     C
# 491   ANBU-1491 2025-02-04 04:23:00  Shikamaru       kumo  7964.39     S
# 1112  ANBU-2112 2025-02-05 12:14:00      Gaara       kumo  7875.66     S
# 711   ANBU-1711 2025-02-02 15:24:00      Gaara       kumo  7847.07     B
# 863   ANBU-1863 2025-02-06 11:12:00     Temari     lluvia  6920.15     C
# 439   ANBU-1439 2025-02-01 02:55:00  Shikamaru     lluvia  6883.00     S
# 1201  ANBU-2201 2025-02-06 16:25:00     Sasuke     lluvia  6494.72     A
# 891   ANBU-1891 2025-02-04 14:45:00     Sasuke     lluvia  6209.03     B
# 94    ANBU-1094 2025-02-04 06:57:00     Sasuke     lluvia  5841.01     C
# 706   ANBU-1706 2025-02-05 00:48:00     Temari       suna  7954.05     D
# 12    ANBU-1012 2025-02-06 07:00:00  Shikamaru       suna  7975.82     B
# 480   ANBU-1480 2025-02-05 14:43:00     Naruto       suna  7872.46     D
# 871   ANBU-1871 2025-02-01 19:15:00    Kakashi       suna  7897.64     S
# 1036  ANBU-2036 2025-02-03 18:34:00    Kankuro       suna  7960.35     D
#
#           Estado                            Descripcion
# 1221       Éxito      Infiltrado de la Lluvia detectado
# 742        Fallo                 Escolta de persona VIP
# 512     En curso      Infiltrado de la Lluvia detectado
# 1232       Fallo        Movimiento sospechoso detectado
# 1263    En curso                Sustitución de guardias
# 530     En curso        Movimiento sospechoso detectado
# 738        Fallo                     Enemigo a la vista
# 777        Éxito      Recuperación de pergamino secreto
# 1104       Fallo        Movimiento sospechoso detectado
# 1100       Fallo                 Escolta de persona VIP
# 1292       Fallo  Misión de reconocimiento en fronteras
# 216     En curso          Vigilancia de puesto avanzado
# 637        Fallo  Misión de reconocimiento en fronteras
# 150        Fallo                Posible espía detectado
# 987   Sospechoso                     Patrulla rutinaria
# 1002    En curso                Sustitución de guardias
# 340        Éxito                     Patrulla rutinaria
# 1416  Sospechoso  Misión de reconocimiento en fronteras
# 467     En curso          Vigilancia de puesto avanzado
# 277        Fallo                 Escolta de persona VIP
# 1060       Éxito                 Escolta de persona VIP
# 172   Sospechoso  Misión de reconocimiento en fronteras
# 899   Sospechoso                Sustitución de guardias
# 1048       Éxito                     Enemigo a la vista
# 885        Éxito                Sustitución de guardias
# 286   Sospechoso          Vigilancia de puesto avanzado
# 634        Éxito                     Enemigo a la vista
# 491     En curso                 Escolta de persona VIP
# 1112    En curso        Movimiento sospechoso detectado
# 711   Sospechoso                Posible espía detectado
# 863        Fallo      Recuperación de pergamino secreto
# 439     En curso      Infiltrado de la Lluvia detectado
# 1201  Sospechoso      Recuperación de pergamino secreto
# 891   Sospechoso                Sustitución de guardias
# 94         Fallo                 Escolta de persona VIP
# 706   Sospechoso                Sustitución de guardias
# 12         Éxito      Recuperación de pergamino secreto
# 480        Éxito  Misión de reconocimiento en fronteras
# 871   Sospechoso                 Escolta de persona VIP
# 1036       Fallo                Posible espía detectado
# /tmp/ipython-input-1905194082.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["aldea"] = df["aldea"].str.lower().str.strip()
# /tmp/ipython-input-1905194082.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ts'] = pd.to_datetime(df['ts'], errors='coerce')
